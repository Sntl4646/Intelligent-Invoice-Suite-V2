# %%
pip install "PyMuPDF>=1.24.8"
# Out:
#   Cell In[3], line 1
#     pip install "PyMuPDF>=1.24.8"
#         ^
# SyntaxError: invalid syntax

# %%
fitz.__doc__
'PyMuPDF 1.24.8: Python bindings for the MuPDF library.'
exit()
