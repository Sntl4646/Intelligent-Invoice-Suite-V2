# %%
import psycopg2

conn = psycopg2.connect(
    dbname="invoice_ai",
    user="postgres",
    password="Welcome123",
    host="localhost",
    port="5432"
)
print("✅ Connection successful!")
conn.close()
